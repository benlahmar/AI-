# %% [markdown]
# # 🐍 Atelier 1 : Initialisation à Python pour l'Intelligence Artificielle
# ###          Auteur: Pr BENLAHMAR EL HABIB
#
# ## 🎯 Objectifs de l'Atelier
#
# Ce premier atelier a pour but de vous familiariser avec les outils de base (Notebooks Jupyter) et les structures de données fondamentales de Python, essentielles à toute manipulation de données en Intelligence Artificielle (IA).
#
# * Comprendre l'environnement **Jupyter Notebook**.
# * Maîtriser les types de données de base.
# * Manipuler les structures de données essentielles (**Listes** et **Dictionnaires**).
# * Utiliser les structures de contrôle de flux (**Boucles** et **Conditions**).

# %% [markdown]
# ## 🛠️ Préparation de l'Environnement (5 minutes)
#
# 1.  **Lancement de VS Code :** Ouvrez Visual Studio Code.
# 2.  **Vérification de l'Interpréteur :** Assurez-vous que l'interpréteur Python **`Conda: ia_tp`** est sélectionné en bas à droite de l'écran.
# 3.  **Création du Notebook :** Si ce fichier n'est pas encore sauvegardé, nommez-le `atelier_python_base.ipynb`.

# %%
# TEST de l'environnement : Exécutez cette cellule (Shift + Entrée)
print("Environnement prêt pour l'IA !")

# %% [markdown]
# ---
#
# ## 1. Structure du Notebook Jupyter
#
# Un Notebook est composé de cellules que vous exécutez de manière interactive.
#
# | Type de Cellule | Fonction | Raccourci d'Exécution |
# | :--- | :--- | :--- |
# | **Code** | Écrire et exécuter du code Python. | `Shift + Entrée` |
# | **Markdown** | Ajouter du texte formaté, des titres, des explications et de la documentation. | `Shift + Entrée` |
#
# ### ✏️ Exercice 1.1 (Markdown)
#
# 1.  Créez une cellule de type **Markdown** juste après celle-ci.
# 2.  Écrivez le titre `# Mon Premier Notebook IA` suivi d'une courte description de ce que vous allez y faire.

# %% [markdown]
# ---
#
# ## 2. Types de Données Fondamentaux
#
# Python est capable de gérer différents types d'informations. Utilisez `type()` pour vérifier le type d'une variable.
#
# | Type | Description | Exemple |
# | :--- | :--- | :--- |
# | **`int`** | Nombres entiers (compteurs, indices) | `nombre_echantillons = 500` |
# | **`float`** | Nombres décimaux (poids de modèles, probabilités) | `precision = 0.985` |
# | **`str`** | Chaînes de caractères (noms, étiquettes) | `modele_type = "Regression"` |
# | **`bool`** | Valeurs booléennes (vrai/faux) | `entrainement_termine = True` |
#
# ### ✏️ Exercice 2.1 (Types)
#
# Dans la cellule de code ci-dessous, définissez une variable pour chaque type ci-dessus et utilisez la fonction **`type()`** pour vérifier son type.

# %%
variable_int = 100
print(type(variable_int)) 

# Ajoutez vos autres variables (float, str, bool) ici :

# %% [markdown]
# ---
#
# ## 3. Structures de Données Essentielles
#
# ### A. Les Listes (`list`) : La Collection Ordonnée
#
# Les listes sont des collections **modifiables** d'éléments.
# * **Indexation :** Les éléments sont accédés par leur position, qui commence à **0**.
# * **Slicing (Découpage) :** `ma_liste[début : fin (exclue)]`.
#
# ### ✏️ Exercice 3.1 (Listes)
#
# 1.  Créez une liste nommée `predictions`.
# 2.  Affichez la **première** prédiction.
# 3.  Affichez la **dernière** prédiction en utilisant l'indice négatif (`[-1]`).
# 4.  Utilisez le *slicing* pour afficher uniquement les prédictions du **deuxième au quatrième** élément (inclus).

# %%
predictions = ['Chien', 'Chat', 'Oiseau', 'Chat', 'Chien', 'Poisson']

# 1. Affichez la première prédiction

# 2. Affichez la dernière prédiction

# 3. Affichez le slicing demandé

# %% [markdown]
# ### B. Les Dictionnaires (`dict`) : Clé-Valeur
#
# Les dictionnaires stockent des données sous forme de paires **Clé : Valeur**. Idéal pour représenter un échantillon de données avec des attributs.
#
# ### ✏️ Exercice 3.2 (Dictionnaires)
#
# 1.  Créez un dictionnaire nommé `image_data` avec les clés : `id_image`, `resolution` et `is_couleur`.
# 2.  Affichez la valeur de la clé `resolution`.
# 3.  Changez la valeur de la clé `resolution` à `"1024x768"`.

# %%
image_data = {
    'id_image': 'A1B2C3',
    'resolution': '640x480',
    'is_couleur': True
}

# 1. Affichez la résolution

# 2. Changez la résolution

# 3. Vérifiez le changement
print(image_data)

# %% [markdown]
# ---
#
# ## 4. Structures de Contrôle de Flux
#
# ### A. Les Conditionnelles (`if`, `elif`, `else`)
#
# ### ✏️ Exercice 4.1 (Conditions)
#
# 1.  Définissez `seuil_validation = 0.7` et `score_modele = 0.65`.
# 2.  Écrivez une condition `if`/`else` qui affiche : "Modèle Validé" ou "Modèle à Re-entraîner".

# %%
seuil_validation = 0.7
score_modele = 0.65

# Votre structure conditionnelle ici

# %% [markdown]
# ### B. Les Boucles (`for`)
#
# Pour itérer sur une collection d'éléments.
#
# ### ✏️ Exercice 4.2 (Boucles et Conditions Combinées)
#
# Utilisez une boucle `for` et une condition `if` pour compter le nombre de fois où l'étiquette **'Chat'** apparaît dans la liste `predictions`.
#
# 1.  Initialisez un compteur : `compteur_chats = 0`.
# 2.  Parcourez la liste `predictions`.
# 3.  Incrémentez le compteur si l'élément est 'Chat'.

# %%
predictions = ['Chien', 'Chat', 'Oiseau', 'Chat', 'Chien', 'Poisson']
compteur_chats = 0

# Votre boucle for ici


print(f"Nombre total de Chats : {compteur_chats}")

# %% [markdown]
# ---
#
# ##  Conclusion de l'Atelier
#
# Nous avons couvert les bases de la syntaxe Python et de ses structures de données fondamentales.
#
# Ces listes et dictionnaires sont les blocs de construction qui seront utilisés dans le prochain atelier pour créer des objets plus complexes et performants comme les tableaux **NumPy** et les DataFrames **Pandas**.
#
# **Prochaine Étape :** Introduction aux fonctions et aux librairies scientifiques (NumPy et Pandas).
