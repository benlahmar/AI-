# %% [markdown]
# # 🔁 Atelier 3 : Maîtrise des Séquences, Boucles et Dictionnaires
# #### Auteur: Pr BENLAHMAR EL HABIB
#
#
# ## 🎯 Objectifs de l'Atelier
#
# Cet atelier consolide votre capacité à parcourir, filtrer et organiser des données en Python, compétences indispensables pour préparer et analyser les jeux de données d'IA.
#
# * **Séquences :** Revoir les **Listes** et les **Tuples** (séquences immuables).
# * **Tableaux Associatifs :** Maîtriser les **Dictionnaires** (`dict`).
# * **Boucles :** Utiliser efficacement les boucles `for` pour l'itération et le traitement de données.

# %% [markdown]
# ---
#
# ## 1. Les Séquences Python : Listes et Tuples
#
# Une séquence est une collection ordonnée d'éléments.
#
# ### A. Rappel : La Liste (`list`)
#
# Les listes sont **mutables** (modifiables). Elles sont utilisées pour les ensembles de données dont la taille ou le contenu est susceptible de changer.
#
# ### ✏️ Exercice 1.1 (Opérations sur Listes)
#
# 1.  Créez la liste `points_modele = [0.75, 0.88, 0.65, 0.92]`.
# 2.  Ajoutez un nouveau point de 0.81 à la fin de la liste.
# 3.  Retirez le troisième élément de la liste (l'index 2, qui est `0.65`).
# 4.  Affichez la liste finale.

# %%
points_modele = [0.75, 0.88, 0.65, 0.92]

# 1. Ajoutez 0.81 à la fin (méthode .append())


# 2. Retirez l'élément à l'index 2 (méthode .pop() ou instruction del)


# 3. Affichez la liste finale
print(points_modele)

# %% [markdown]
# ### B. Le Tuple (`tuple`)
#
# Les tuples sont des séquences **immuables** (non modifiables). On les utilise pour des données qui ne doivent jamais changer, comme les coordonnées géographiques ou les paramètres d'un modèle finalisé.
#
# ### ✏️ Exercice 1.2 (Tuple)
#
# 1.  Créez un tuple nommé `coordonnees_gpu` contenant `(48.8584, 2.2945, 'Serveur Alpha')`.
# 2.  Affichez la latitude (le premier élément).
# 3.  **Tentez** de modifier le nom du serveur (par exemple : `coordonnees_gpu[2] = 'Serveur Beta'`). **Observez l'erreur** générée et expliquez-la en Markdown.

# %%
coordonnees_gpu = (48.8584, 2.2945, 'Serveur Alpha')

# 1. Affichez la latitude


# 2. Tentez de modifier (Cette ligne devrait générer une erreur intentionnelle)
# coordonnees_gpu[2] = 'Serveur Beta'

# %% [markdown]
# ---
#
# ## 2. Dictionnaires (Tableaux Associatifs) : La Structure Clé-Valeur
#
# Le **Dictionnaire** (`dict`) est la structure de données utilisée pour stocker les attributs d'un objet (comme un enregistrement de base de données). L'accès se fait par une **clé** et non par un index numérique.
#
# ### ✏️ Exercice 2.1 (Manipulation de Dictionnaire)
#
# Nous allons représenter un neurone avec ses poids et son biais.
#
# 1.  Affichez la valeur du `poids_init`.
# 2.  Ajoutez une nouvelle propriété au dictionnaire : `'fonction_activation'` avec la valeur `'sigmoid'`.
# 3.  Modifiez la valeur de la clé `'biais'` à `0.05`.
# 4.  Affichez le dictionnaire complet pour vérifier les modifications.

# %%
neurone = {
    'id': 101,
    'poids_init': 0.75,
    'biais': 0.15,
    'entraine': False
}

# 1. Affichez le poids initial


# 2. Ajoutez 'fonction_activation'


# 3. Modifiez le 'biais'


# 4. Affichez le dictionnaire final

# %% [markdown]
# ---
#
# ## 3. Les Boucles `for` : Itération sur les Séquences et les Dictionnaires
#
# La boucle `for` est l'outil principal pour traiter séquentiellement les données.
#
# ### A. Boucle sur une Séquence (Liste)
#
# ### ✏️ Exercice 3.1 (Boucle et Condition)
#
# Dans un processus de filtrage, nous devons rejeter les résultats ayant une faible confiance.
#
# 1.  Parcourez la liste `confiances`.
# 2.  Utilisez une condition `if` pour n'afficher que les résultats dont la confiance est **supérieure à 0.8**.

# %%
confiances = [0.91, 0.45, 0.82, 0.77, 0.99, 0.55]
seuil = 0.8

# Votre boucle for ici :
for confiance in confiances:
    # Votre condition if ici
    pass

# %% [markdown]
# ### B. Itérer sur un Dictionnaire
#
# Lorsqu'on boucle sur un dictionnaire, on peut obtenir :
#
# 1.  Uniquement les **clés** (`.keys()`).
# 2.  Uniquement les **valeurs** (`.values()`).
# 3.  Les deux (Clé et Valeur) en même temps (`.items()`).
#
# ### ✏️ Exercice 3.2 (Itération sur un Dictionnaire)
#
# 1.  Utilisez la méthode `.items()` pour parcourir le dictionnaire `resultat_ia`.
# 2.  Pour chaque paire (Clé, Valeur), affichez la clé (le nom de la métrique) et la valeur associée.
# 3.  Ajoutez une condition pour afficher en plus grand (ou en majuscules) les valeurs si la métrique est 'Accuracy'.

# %%
resultat_ia = {
    'Accuracy': 0.95,
    'Loss': 0.12,
    'F1_Score': 0.93
}

# Votre boucle for pour itérer sur les items :
for metrique, valeur in resultat_ia.items():
    # Votre code ici
    pass

# %% [markdown]
# ---
#
# ## ✅ Conclusion de l'Atelier
#
# Vous avez consolidé votre maîtrise des structures de données de base qui servent de fondations aux objets plus complexes comme **NumPy** et **Pandas**.
#
# * Les **listes** gèrent les données dynamiques.
# * Les **tuples** gèrent les données constantes.
# * Les **dictionnaires** gèrent les données structurées (Clé-Valeur).
#
# Ces compétences vous permettront d'écrire des scripts Python robustes pour le pré-traitement des données.
